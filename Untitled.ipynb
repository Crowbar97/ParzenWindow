# %%
import numpy as np
from scipy.special import gamma
from operator import add
from math import sqrt, pi, exp
from functools import reduce
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'x-large',
          'axes.titlesize': 'x-large',
          'xtick.labelsize': 'x-large',
          'ytick.labelsize': 'x-large'}
pylab.rcParams.update(params)

# %%
class Distributions:
    @staticmethod
    def normal_density(x, mean, variance):
        return 1 / sqrt(2 * pi * variance ** 2) * exp(- (x - mean) ** 2 / (2 * variance ** 2))

    @staticmethod
    def normal(mean, variance, count):
        return np.random.normal(mean, variance, int(count))

    @staticmethod
    def uniform_density(x, left_bound, right_bound):
        if left_bound <= x <= right_bound:
            return 1 / (right_bound - left_bound)
        return 0

    @staticmethod
    def uniform(left_bound, right_bound, count):
        return np.random.uniform(left_bound, right_bound, int(count))

    @staticmethod
    def beta_density(x, a, b):
        return gamma(a + b) / (gamma(a) * gamma(b)) * x ** (a - 1) * (1 - x) ** (b - 1)

    @staticmethod
    def beta(a, b, count):
        return np.random.beta(a, b, int(count))

# %%
class Parzen:
    @staticmethod
    def rect_kernel(z):
        return 0.5 * int(abs(z) < 1)

    @staticmethod
    def density(x, points, h):
        sum = 0
        for p in points:
            sum += Parzen.rect_kernel((x - p) / h)
        return 1 / (len(points) * h) * sum

    @staticmethod
    def plot(distr_name, distr_points,
             check_points,
             distr_density, est_density,
             point_count, h):
        plt.figure()

        plt.plot(distr_points, [0] * len(distr_points), 'g|', label=distr_name + " distr")
        plt.plot(check_points, distr_density, 'go-', label=distr_name + " density")
        plt.stem(check_points, est_density, '-.', basefmt=" ", label="est density")

        plt.title("Parzen window density estimation"
                  "\npoint count = " + str(point_count)
                  + "\nbest h = " + str(h), fontsize=20)
        plt.xlabel("x", fontsize=20)
        plt.ylabel("density", fontsize=20)
        plt.grid(True)
        plt.legend(loc=0, fontsize=20)

        plt.show()
        pass

    @staticmethod
    def estimate_best_h(distr_name, distr_density,
                        distr_points, check_points,
                        h_min=0.01, h_max=1, h_step=0.01):
        min_error = 1e9
        best_h = 0
        best_density = []
        print("Estimation", distr_name, "distribution density...")
        for h in np.arange(h_min, h_max, h_step):
            est_density = list(map(lambda p: Parzen.density(p, distr_points, h), check_points))
            mse = Distances.l2(distr_density, est_density)
            print("h =", round(h, 2), ": l2 =", mse)
            if mse < min_error:
                min_error = mse
                best_h = h
                best_density = est_density

        print("best h =", round(best_h, 2), ": l2 =", min_error)

        Parzen.plot(distr_name,
                    distr_points,
                    check_points,
                    distr_density, best_density,
                    len(distr_points), round(best_h, 2))

# %%
class Distances:
    @staticmethod
    def l2(d1, d2):
        return sqrt(reduce(add, map(lambda y1, y2: (y1 - y2) ** 2, d1, d2)))

# %%
# conditions
point_count = 1e3
check_points = np.arange(-4, 4, 0.1)

# normal distribution
mean, variance = 0, 1
normal_density = list(map(lambda p: Distributions.normal_density(p, mean, variance), check_points))
normal_points = Distributions.normal(mean, variance, point_count)
Parzen.estimate_best_h("normal", normal_density,
                       normal_points, check_points)
# Out:
# Estimation normal distribution density...
# h = 0.01 : l2 = 0.6312687723190398
# h = 0.02 : l2 = 0.4366775893389523
# h = 0.03 : l2 = 0.336408051654927
# h = 0.04 : l2 = 0.3078236104796943
# h = 0.05 : l2 = 0.30594359223687284
# h = 0.06 : l2 = 0.2968766639278188
# h = 0.07 : l2 = 0.2714322170174521
# h = 0.08 : l2 = 0.2417019609096546
# h = 0.09 : l2 = 0.211024866399275
# h = 0.1 : l2 = 0.20371622052231175
# h = 0.11 : l2 = 0.20719340868400926
# h = 0.12 : l2 = 0.18549506066372223
# h = 0.13 : l2 = 0.17649913431329486
# h = 0.14 : l2 = 0.16699636973296478
# h = 0.15 : l2 = 0.17278448614406514
# h = 0.16 : l2 = 0.16498373728360655
# h = 0.17 : l2 = 0.1522823715564948
# h = 0.18 : l2 = 0.14742214361176045
# h = 0.19 : l2 = 0.1326452388019363
# h = 0.2 : l2 = 0.12999527471957845
# h = 0.21 : l2 = 0.1287046400297726
# h = 0.22 : l2 = 0.11759921038681609
# h = 0.23 : l2 = 0.10989771116532202
# h = 0.24 : l2 = 0.1034445471939021
# h = 0.25 : l2 = 0.11032408721412536
# h = 0.26 : l2 = 0.1104863834926293
# h = 0.27 : l2 = 0.1102805404684154
# h = 0.28 : l2 = 0.10543711160442631
# h = 0.29 : l2 = 0.10283806196975703
# h = 0.3 : l2 = 0.09836590139978796
# h = 0.31 : l2 = 0.09853896207083761
# h = 0.32 : l2 = 0.09979185878711488
# h = 0.33 : l2 = 0.09609715853565957
# h = 0.34 : l2 = 0.09268487344104098
# h = 0.35 : l2 = 0.09627670388205205
# h = 0.36 : l2 = 0.09483594704308353
# h = 0.37 : l2 = 0.09192910410436575
# h = 0.38 : l2 = 0.0892078572047222
# h = 0.39 : l2 = 0.08651006169715166
# h = 0.4 : l2 = 0.08397430678776723
# h = 0.41 : l2 = 0.08814930364615618
# h = 0.42 : l2 = 0.09130374373616743
# h = 0.43 : l2 = 0.09012021593273627
# h = 0.44 : l2 = 0.0875267091470662
# h = 0.45 : l2 = 0.09090829727572147
# h = 0.46 : l2 = 0.09121219927156556
# h = 0.47 : l2 = 0.09060617657814841
# h = 0.48 : l2 = 0.0903301412023448
# h = 0.49 : l2 = 0.09057912080985281
# h = 0.5 : l2 = 0.08918102446437372
# h = 0.51 : l2 = 0.09585560571030474
# h = 0.52 : l2 = 0.10005693813066001
# h = 0.53 : l2 = 0.10194039388059487
# h = 0.54 : l2 = 0.10235622074562759
# h = 0.55 : l2 = 0.10699248832125409
# h = 0.56 : l2 = 0.10741738719958885
# h = 0.57 : l2 = 0.10844971076309987
# h = 0.58 : l2 = 0.10908651301132441
# h = 0.59 : l2 = 0.1102577300764704
# h = 0.6 : l2 = 0.10908014057498203
# h = 0.61 : l2 = 0.11508169472953117
# h = 0.62 : l2 = 0.11863259561130865
# h = 0.63 : l2 = 0.12094968119587149
# h = 0.64 : l2 = 0.1235616492304772
# h = 0.65 : l2 = 0.12798314706181402
# h = 0.66 : l2 = 0.12804820891605453
# h = 0.67 : l2 = 0.13004525800533753
# h = 0.68 : l2 = 0.13090937780784317
# h = 0.69 : l2 = 0.13230140171298596
# h = 0.7 : l2 = 0.13184292511141765
# h = 0.71 : l2 = 0.13730930588174348
# h = 0.72 : l2 = 0.14121481069432756
# h = 0.73 : l2 = 0.14427236714341915
# h = 0.74 : l2 = 0.14787935842447378
# h = 0.75 : l2 = 0.15177987013640307
# h = 0.76 : l2 = 0.1528791586472862
# h = 0.77 : l2 = 0.15576064163020117
# h = 0.78 : l2 = 0.1572931113991374
# h = 0.79 : l2 = 0.1595885073305185
# h = 0.8 : l2 = 0.15988913748649417
# h = 0.81 : l2 = 0.16538794393710113
# h = 0.82 : l2 = 0.16955589673909696
# h = 0.83 : l2 = 0.17326521165931597
# h = 0.84 : l2 = 0.1772257295969309
# h = 0.85 : l2 = 0.18094673126914057
# h = 0.86 : l2 = 0.18231743214004442
# h = 0.87 : l2 = 0.18542465752881723
# h = 0.88 : l2 = 0.18759082293684723
# h = 0.89 : l2 = 0.19047107829184481
# h = 0.9 : l2 = 0.1912324185287418
# h = 0.91 : l2 = 0.19678155062949018
# h = 0.92 : l2 = 0.20127226669838574
# h = 0.93 : l2 = 0.20527466075900058
# h = 0.94 : l2 = 0.2096617321198861
# h = 0.95 : l2 = 0.21320325061711956
# h = 0.96 : l2 = 0.2149605069259775
# h = 0.97 : l2 = 0.21843519541828374
# h = 0.98 : l2 = 0.2209694205834079
# h = 0.99 : l2 = 0.22432404385247695
# best h = 0.4 : l2 = 0.08397430678776723

# %%
 # uniform  distribution
left_bound = -2
right_bound = 2
uniform_density = list(map(lambda p: Distributions.uniform_density(p, left_bound, right_bound), check_points))
uniform_points = Distributions.uniform(left_bound, right_bound, point_count)
Parzen.estimate_best_h("uniform", uniform_density,
                       uniform_points, check_points)
# Out:
# Estimation uniform distribution density...
# h = 0.01 : mse = 0.006937500000000002
# h = 0.02 : mse = 0.0032187500000000003
# h = 0.03 : mse = 0.002184027777777777
# h = 0.04 : mse = 0.0015351562500000003
# h = 0.05 : mse = 0.0016475000000000003
# h = 0.06 : mse = 0.0012760416666666662
# h = 0.07 : mse = 0.000986607142857143
# h = 0.08 : mse = 0.0008349609375000001
# h = 0.09 : mse = 0.0007916666666666669
# h = 0.1 : mse = 0.0008425
# h = 0.11 : mse = 0.0008367768595041319
# h = 0.12 : mse = 0.0008250868055555557
# h = 0.13 : mse = 0.0007975221893491123
# h = 0.14 : mse = 0.0008478954081632655
# h = 0.15 : mse = 0.0008722222222222221
# h = 0.16 : mse = 0.0008659667968750004
# h = 0.17 : mse = 0.0007955233564013841
# h = 0.18 : mse = 0.0007725694444444441
# h = 0.19 : mse = 0.0007763157894736846
# h = 0.2 : mse = 0.0008239062500000002
# h = 0.21 : mse = 0.0008455215419501136
# h = 0.22 : mse = 0.0008719008264462811
# h = 0.23 : mse = 0.0008620628544423437
# h = 0.24 : mse = 0.000882595486111111
# h = 0.25 : mse = 0.0009035999999999995
# h = 0.26 : mse = 0.000915957840236686
# h = 0.27 : mse = 0.0009155092592592591
# h = 0.28 : mse = 0.0009312021683673474
# h = 0.29 : mse = 0.00095986920332937
# h = 0.3 : mse = 0.001025694444444444
# h = 0.31 : mse = 0.0010611992715920916
# h = 0.32 : mse = 0.0010524902343750002
# h = 0.33 : mse = 0.0010666035353535358
# h = 0.34 : mse = 0.0010516868512110724
# h = 0.35 : mse = 0.0010737244897959185
# h = 0.36 : mse = 0.001119068287037037
# h = 0.37 : mse = 0.0011452930971512048
# h = 0.38 : mse = 0.0011443905817174517
# h = 0.39 : mse = 0.0011518326758711373
# h = 0.4 : mse = 0.0012129687499999999
# h = 0.41 : mse = 0.0012510782272456872
# h = 0.42 : mse = 0.0012726403061224492
# h = 0.43 : mse = 0.001282602082206598
# h = 0.44 : mse = 0.0013141464359504135
# h = 0.45 : mse = 0.001333703703703704
# h = 0.46 : mse = 0.001367704395085066
# h = 0.47 : mse = 0.0013849734042553192
# h = 0.48 : mse = 0.0013962402343749999
# h = 0.49 : mse = 0.001425265514369013
# h = 0.5 : mse = 0.0014733249999999997
# h = 0.51 : mse = 0.0014928873510188382
# h = 0.52 : mse = 0.0015283607618343197
# h = 0.53 : mse = 0.0015281127625489505
# h = 0.54 : mse = 0.0015795824759945129
# h = 0.55 : mse = 0.0016156198347107443
# h = 0.56 : mse = 0.0016400271045918363
# h = 0.57 : mse = 0.00166357917820868
# h = 0.58 : mse = 0.0016772629310344831
# h = 0.59 : mse = 0.0016981829933927033
# h = 0.6 : mse = 0.0017363194444444444
# h = 0.61 : mse = 0.001757810400429992
# h = 0.62 : mse = 0.0018075897502601447
# h = 0.63 : mse = 0.0018128070672713535
# h = 0.64 : mse = 0.0018552398681640626
# h = 0.65 : mse = 0.0018725443786982245
# h = 0.66 : mse = 0.0018971676997245179
# h = 0.67 : mse = 0.0019184743261305408
# h = 0.68 : mse = 0.0019350400086505196
# h = 0.69 : mse = 0.001957873871035497
# h = 0.7 : mse = 0.001979923469387755
# h = 0.71 : mse = 0.0019924990081333074
# h = 0.72 : mse = 0.002032443576388888
# h = 0.73 : mse = 0.002049745496340777
# h = 0.74 : mse = 0.002073902027027027
# h = 0.75 : mse = 0.0020890222222222227
# h = 0.76 : mse = 0.002109569771468143
# h = 0.77 : mse = 0.0021266497301399893
# h = 0.78 : mse = 0.0021499527449046684
# h = 0.79 : mse = 0.0021629947123858358
# h = 0.8 : mse = 0.002174921875
# h = 0.81 : mse = 0.002192034369760708
# h = 0.82 : mse = 0.002228742192147532
# h = 0.83 : mse = 0.002252145630715634
# h = 0.84 : mse = 0.00228969139739229
# h = 0.85 : mse = 0.0023078373702422146
# h = 0.86 : mse = 0.002322471606273662
# h = 0.87 : mse = 0.0023475896749900914
# h = 0.88 : mse = 0.0023838052040289254
# h = 0.89 : mse = 0.0023924536043428857
# h = 0.9 : mse = 0.002397561728395062
# h = 0.91 : mse = 0.002416163506822848
# h = 0.92 : mse = 0.0024443525519848765
# h = 0.93 : mse = 0.002474957365013296
# h = 0.94 : mse = 0.0025097682775011326
# h = 0.95 : mse = 0.002529134349030471
# h = 0.96 : mse = 0.002549730088975694
# h = 0.97 : mse = 0.0025736827771282813
# h = 0.98 : mse = 0.0026145486255726783
# h = 0.99 : mse = 0.0026300951433527184
# best h = 0.18 : mse = 0.0007725694444444441

# %%
 # beta  distribution
check_points = np.arange(0.01, 1, 0.01)
a = 0.5
b = 0.5
beta_density = list(map(lambda p: Distributions.beta_density(p, a, b), check_points))
beta_points = Distributions.beta(a, b, point_count)
Parzen.estimate_best_h("beta", beta_density,
                       beta_points, check_points)
# Out:
# Estimation beta distribution density...
# h = 0.01 : l2 = 2.7546272100702427
# h = 0.02 : l2 = 2.197753001419367
# h = 0.03 : l2 = 2.128912210728349
# h = 0.04 : l2 = 2.4300554343338505
# h = 0.05 : l2 = 2.689645722435549
# h = 0.06 : l2 = 2.972143412527559
# h = 0.07 : l2 = 3.2126911409897994
# h = 0.08 : l2 = 3.4287918087739935
# h = 0.09 : l2 = 3.607496990222639
# h = 0.1 : l2 = 3.763753967330075
# h = 0.11 : l2 = 3.892062955435197
# h = 0.12 : l2 = 4.019314305376035
# h = 0.13 : l2 = 4.145300579593905
# h = 0.14 : l2 = 4.274966175262829
# h = 0.15 : l2 = 4.39073773130264
# h = 0.16 : l2 = 4.49999559549271
# h = 0.17 : l2 = 4.598389251260004
# h = 0.18 : l2 = 4.689386425274811
# h = 0.19 : l2 = 4.773313973431503
# h = 0.2 : l2 = 4.853854215123671
# h = 0.21 : l2 = 4.927833988608442
# h = 0.22 : l2 = 4.998685707793644
# h = 0.23 : l2 = 5.0652678884381865
# h = 0.24 : l2 = 5.125419939832562
# h = 0.25 : l2 = 5.1833270088126655
# h = 0.26 : l2 = 5.238286907471712
# h = 0.27 : l2 = 5.290859299888671
# h = 0.28 : l2 = 5.336545782945625
# h = 0.29 : l2 = 5.378458007282404
# h = 0.3 : l2 = 5.41637076244646
# h = 0.31 : l2 = 5.45850956691493
# h = 0.32 : l2 = 5.500285094354368
# h = 0.33 : l2 = 5.538384462275027
# h = 0.34 : l2 = 5.5710732326447845
# h = 0.35 : l2 = 5.603914240156713
# h = 0.36 : l2 = 5.632958725546476
# h = 0.37 : l2 = 5.663947090408737
# h = 0.38 : l2 = 5.693384347402472
# h = 0.39 : l2 = 5.719381754200054
# h = 0.4 : l2 = 5.746052192107219
# h = 0.41 : l2 = 5.769170991404713
# h = 0.42 : l2 = 5.790193894167767
# h = 0.43 : l2 = 5.811184716285098
# h = 0.44 : l2 = 5.831834497373161
# h = 0.45 : l2 = 5.850980253339422
# h = 0.46 : l2 = 5.8717053712166285
# h = 0.47 : l2 = 5.893902016013171
# h = 0.48 : l2 = 5.9132189048456905
# h = 0.49 : l2 = 5.934444437286343
# h = 0.5 : l2 = 5.9554227434520355
# h = 0.51 : l2 = 5.974047262940609
# h = 0.52 : l2 = 5.992534820398853
# h = 0.53 : l2 = 6.006672662288261
# h = 0.54 : l2 = 6.019767076076065
# h = 0.55 : l2 = 6.033471055235629
# h = 0.56 : l2 = 6.0457528526467055
# h = 0.57 : l2 = 6.057212339294992
# h = 0.58 : l2 = 6.068767644490154
# h = 0.59 : l2 = 6.079482330549807
# h = 0.6 : l2 = 6.087763305048518
# h = 0.61 : l2 = 6.096411612739413
# h = 0.62 : l2 = 6.103290586880068
# h = 0.63 : l2 = 6.108819952859774
# h = 0.64 : l2 = 6.115918784014194
# h = 0.65 : l2 = 6.121865646495274
# h = 0.66 : l2 = 6.128594339553057
# h = 0.67 : l2 = 6.133743647019281
# h = 0.68 : l2 = 6.137196768879688
# h = 0.69 : l2 = 6.139958380402923
# h = 0.7 : l2 = 6.14514535868695
# h = 0.71 : l2 = 6.150673499102014
# h = 0.72 : l2 = 6.1564604527173845
# h = 0.73 : l2 = 6.160870883732447
# h = 0.74 : l2 = 6.165174466712892
# h = 0.75 : l2 = 6.169365256810934
# h = 0.76 : l2 = 6.173959381064449
# h = 0.77 : l2 = 6.177923209712919
# h = 0.78 : l2 = 6.181457324920512
# h = 0.79 : l2 = 6.184850211063912
# h = 0.8 : l2 = 6.1876013567491075
# h = 0.81 : l2 = 6.190695300068943
# h = 0.82 : l2 = 6.1935106905430315
# h = 0.83 : l2 = 6.195961505143023
# h = 0.84 : l2 = 6.197888628369412
# h = 0.85 : l2 = 6.199495371236539
# h = 0.86 : l2 = 6.199238010019739
# h = 0.87 : l2 = 6.199484926811644
# h = 0.88 : l2 = 6.20019663279866
# h = 0.89 : l2 = 6.202264511011592
# h = 0.9 : l2 = 6.203579408566665
# h = 0.91 : l2 = 6.204366615684556
# h = 0.92 : l2 = 6.204019246106791
# h = 0.93 : l2 = 6.204208265816534
# h = 0.94 : l2 = 6.203167842528489
# h = 0.95 : l2 = 6.202910006808781
# h = 0.96 : l2 = 6.200497227480869
# h = 0.97 : l2 = 6.199885971576029
# h = 0.98 : l2 = 6.202182539578962
# h = 0.99 : l2 = 6.209310088266169
# best h = 0.03 : l2 = 2.128912210728349
